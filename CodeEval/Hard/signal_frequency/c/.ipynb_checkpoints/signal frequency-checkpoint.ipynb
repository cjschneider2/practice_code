# %%
using Gadfly

# %%
raw_input = open("./input.txt")
# Out:
# IOStream(<file ./input.txt>)

# %%
input = readdlm(raw_input, ' ')
# Out:
# 3x2000 Array{Float64,2}:
#    20.0    22.0    23.0    25.0    27.0  …   64.0   67.0   68.0   72.0   74.0
#  -113.0  -111.0  -111.0  -111.0  -111.0     107.0  107.0  107.0  107.0  107.0
#    59.0    58.0    58.0    58.0    58.0       8.0    8.0    8.0    8.0    8.0

# %%
plot(x = 1:2000, y = input[3,:] , Geom.line)
# Out:
# Plot(...)

# %%
line1 = input[3,:]
# Out:
# 1x2000 Array{Float64,2}:
#  59.0  58.0  58.0  58.0  58.0  58.0  …  7.0  7.0  8.0  8.0  8.0  8.0  8.0

# %%
fft_ = abs(rfft(line1))
# Out:
# 1x2000 Array{Float64,2}:
#  9800.0  22000.3  11027.5  7441.79  …  5621.25  7441.79  11027.5  22000.3

# %%
fft_= fft_[1:2000];

# %%
f = linspace(1, 20000/2, int(2000/2)+1);

# %%
plot(x = f, y = fft_ , Geom.line)
# Out:
# Plot(...)
